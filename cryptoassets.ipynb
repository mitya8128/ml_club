# %%
import numpy as np
import pandas as pd
import sklearn

# %%
data = pd.read_csv('../ml_club/data/cryptoasssets/bitcoin.csv', sep=';')

# %%
data.head()
# Out:
#          Date     Open     High      Low    Close      Volume     MarketCap
# 0  22/11/2017  8077.95  8302.26  8075.47  8253.55  3633530000  134851000000
# 1  21/11/2017  8205.74  8348.66  7762.71  8071.26  4277610000  136967000000
# 2  20/11/2017  8039.07  8336.86  7949.36  8200.64  3488450000  134167000000
# 3  19/11/2017  7766.03  8101.91  7694.10  8036.49  3149320000  129595000000
# 4  18/11/2017  7697.21  7884.99  7463.44  7790.15  3667190000  128425000000

# %%
data['MarketCap'].describe()
# Out:
# count    1.670000e+03
# mean     1.369657e+10
# std      2.117795e+10
# min      7.792550e+08
# 25%      3.775548e+09
# 50%      6.601560e+09
# 75%      1.074598e+10
# max      1.369670e+11
# Name: MarketCap, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test = train_test_split(data, test_size=0.33)

# %%
data_train.corr()
# Out:
#                Open      High       Low     Close    Volume  MarketCap
# Open       1.000000  0.999295  0.999205  0.998655  0.900706   0.999302
# High       0.999295  1.000000  0.998975  0.999416  0.907097   0.998554
# Low        0.999205  0.998975  1.000000  0.999359  0.893145   0.998681
# Close      0.998655  0.999416  0.999359  1.000000  0.900084   0.998013
# Volume     0.900706  0.907097  0.893145  0.900084  1.000000   0.903110
# MarketCap  0.999302  0.998554  0.998681  0.998013  0.903110   1.000000

# %%
import matplotlib as plt
import seaborn as sns

# %%
corr_matrix = data_train.corr()

# %%
sns.heatmap(corr_matrix)

# %% [markdown]
#     -  не отрисовывается heatmap корреляционной матрицы, но и так видно, что признаки высокоскоррелированы:
#     гипотеза про растущий рынок, которая подтверждается (рост всех параметров)

# %% [markdown]
# ### добавим новые признаки

# %%
data_train.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1118.000000  1118.000000  1118.000000  1118.000000  1.118000e+03
# mean    895.987343   923.078971   873.071664   902.101682  2.812021e+08
# std    1296.138993  1346.045262  1263.214954  1314.796559  7.163825e+08
# min      68.500000    75.000000    65.530000    68.430000  0.000000e+00
# 25%     271.405000   277.715000   267.217500   273.712500  1.539100e+07
# 50%     457.300000   462.520000   448.195000   456.705000  3.858105e+07
# 75%     751.807500   765.235000   735.835000   750.920000  1.024448e+08
# max    8205.740000  8348.660000  8075.470000  8253.550000  8.957350e+09
#
#           MarketCap
# count  1.118000e+03
# mean   1.396877e+10
# std    2.177630e+10
# min    7.792550e+08
# 25%    3.886582e+09
# 50%    6.618715e+09
# 75%    1.110090e+10
# max    1.369670e+11

# %%
data_train['open_close_diff'] = data_train['Open'] - data_train['Close']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_train['high_low_diff'] = data_train['High'] - data_train['Low']
data_train.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Date    Open    High     Low   Close    Volume   MarketCap  \
# 1603  03/07/2013   90.41   90.98   76.98   77.53         0  1027160000
# 940   27/04/2015  219.43  233.31  218.02  229.29  38574000  3093200000
# 641   20/02/2016  421.60  441.98  421.60  437.16  93992100  6421310000
# 684   08/01/2016  457.54  462.93  447.94  453.23  56993000  6888600000
# 1004  22/02/2015  244.54  246.39  233.85  235.98  19527000  3390510000
#
#       open_close_diff  high_low_diff
# 1603            12.88          14.00
# 940             -9.86          15.29
# 641            -15.56          20.38
# ...

# %% [markdown]
# **получили новые столбцы
# отсортируем их по дате**

# %%
data_train.head()
data_train.sort_index(ascending=False)
# Out:
#             Date     Open     High      Low    Close      Volume  \
# 1669  28/04/2013   135.30   135.98   132.10   134.21           0
# 1668  29/04/2013   134.44   147.49   134.00   144.54           0
# 1665  02/05/2013   116.38   125.60    92.28   105.21           0
# 1659  08/05/2013   109.60   115.78   109.60   113.57           0
# 1658  09/05/2013   113.20   113.46   109.26   112.67           0
# 1657  10/05/2013   112.80   122.00   111.55   117.20           0
# 1656  11/05/2013   117.70   118.68   113.01   115.24           0
# 1654  13/05/2013   114.82   118.70   114.50   117.98           0
# 1653  14/05/2013   117.98   119.80   110.25   111.50           0
# 1649  18/05/2013   123.50   125.25   122.30   123.50           0
# 1648  19/05/2013   123.21   124.50   119.57   121.99           0
# 1646  21/05/2013   122.02   123.00   121.21   122.88           0
# 1642  25/05/2013   133.10   133.22   128.90   131.98           0
# ...

# %% [markdown]
# #### Попробуем теперь запустить первую модель

# %% [markdown]
# ####  добавим новый признак:
#      *разница между open последующих дат*

# %%
# data_train['open_delta_abs'] = data_train.apply(lambda x: 
#                                                 data_train['Open'].iloc[1:] - 
#                                                 data_train['Open'].iloc[:-1])    #строчка минус след за ней строчка
